# %%
import numpy as np
scores = np.array([3,5,7,8,12,14,18,21])

data_range = scores.max()-scores.min()

q1 = np.percentile(scores,25)
q3 = np.percentile(scores ,75)
iqr = q3-q1

print(f"Range = {data_range}")
print(f"Q1 =  {q1}, Q3= {q3}, IQR = {iqr}")
# Out:
# Range = 18
# Q1 =  6.5, Q3= 15.0, IQR = 8.5
